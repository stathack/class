# %% [markdown]
# # Tutorial Brief

# %% [markdown]
# We will be using tweepy library to perform data mine on twitter.
#
# ##Twitter API
#
# https://apps.twitter.com/
#
# ###Topics:
#
# **Topic 1**: Register You App.
#
# **Topic 2**: Using REST API
#
# **Video Tutorial**:
#
# https://www.youtube.com/user/roshanRush

# %% [markdown]
# # Import the library

# %%
import tweepy
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120

# %% [markdown]
# # Authentication

# %%
consumer_key = "MYzZWA8BPDxrFxIk9g2XA" # Use your own key. To get a key https://apps.twitter.com/
consumer_secret = "mRIq4GdmPm5rGrUeqBbTvjvZS5qH88pLhylBIaiEU"

auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)

api = tweepy.API(auth)

# %% [markdown]
# # REST API

# %% [markdown]
# ## Searching for Tweets

# %% [markdown]
# ###`API.search(q[, lang][, locale][, rpp][, page][, since_id][, geocode][, show_user])`
# ```
#
#     Returns tweets that match a specified query.
#     Parameters:
#
#         q – the search query string
#         lang – Restricts tweets to the given language, given by an ISO 639-1 code.
#         locale – Specify the language of the query you are sending. This is intended for language-specific clients and the default should work in the majority of cases.
#         rpp – The number of tweets to return per page, up to a max of 100.
#         page – The page number (starting at 1) to return, up to a max of roughly 1500 results (based on rpp * page.
#         geocode – Returns tweets by users located within a given radius of the given latitude/longitude. The location is preferentially taking from the Geotagging API, but will fall back to their Twitter profile. The parameter value is specified by “latitide,longitude,radius”, where radius units must be specified as either “mi” (miles) or “km” (kilometers). Note that you cannot use the near operator via the API to geocode arbitrary locations; however you can use this geocode parameter to search near geocodes directly.
#         show_user – When true, prepends “<user>:” to the beginning of the tweet. This is useful for readers that do not display Atom’s author field. The default is false.
#
#     Return type:
#
#     list of SearchResult objects
# ```

# %%
results = api.search(q="IPython")

# %% [markdown]
# ### Inspecting Results

# %%
len(results)
# Out:
# 15

# %%
def print_tweet(tweet):
    print "@%s - %s (%s)" % (tweet.user.screen_name, tweet.user.name, tweet.created_at)
    print tweet.text

tweet=results[1]
print_tweet(tweet)
# Out:
# @HartwigMicheal - Micheal Hartwig (2016-05-02 21:12:08)
# #Imbed matplotlib figure into iPython HTML
# #HowTo #Question #Tech
# https://t.co/TcTZpZbjwT

# %% [markdown]
# ### Inspecting a Status Object

# %%
tweet=results[0]

for param in dir(tweet):
    if not param.startswith("_"):
        print "%s : %s" % (param, eval("tweet." + param))
# Out:
# author : User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)
# contributors : None
# coordinates : None
# created_at : 2016-05-02 21:26:43
# destroy : <bound method Status.destroy of Status(contributors=None, truncated=False, text=u'RT @ProjectJupyter: Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. ht\u2026', is_quote_status=False, in_reply_to_status_id=None, id=727247974309339136, favorite_count=0, _api=<tweepy.api.API object at 0x103b91f10>, author=User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False), _json={u'contributors': None, u'truncated': False, u'text': u'RT @ProjectJupyter: F ...
# entities : {u'symbols': [], u'user_mentions': [{u'id': 2460368252, u'indices': [3, 18], u'id_str': u'2460368252', u'screen_name': u'ProjectJupyter', u'name': u'Project Jupyter'}], u'hashtags': [{u'indices': [51, 59], u'text': u'Jupyter'}, {u'indices': [95, 103], u'text': u'Jupyter'}, {u'indices': [107, 115], u'text': u'IPython'}], u'urls': [{u'url': u'https://t.co/VqlB9RyvpG', u'indices': [139, 140], u'expanded_url': u'http://goo.gl/forms/Cly5djRWtK', u'display_url': u'goo.gl/forms/Cly5djRW\u2026'}]}
# favorite : <bound method Status.favorite of Status(contributors=None, truncated=False, text=u'RT @ProjectJupyter: Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. ht\u2026', is_quote_status=False, in_reply_to_status_id=None, id=727247974309339136, favorite_count=0, _api=<tweepy.api.API object at 0x103b91f10>, author=User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False), _json={u'contributors': None, u'truncated': False, u'text': u'RT @ProjectJupyter: ...
# favorite_count : 0
# favorited : False
# geo : None
# id : 727247974309339136
# id_str : 727247974309339136
# in_reply_to_screen_name : None
# in_reply_to_status_id : None
# in_reply_to_status_id_str : None
# in_reply_to_user_id : None
# in_reply_to_user_id_str : None
# is_quote_status : False
# lang : en
# metadata : {u'iso_language_code': u'en', u'result_type': u'recent'}
# parse : <bound method type.parse of <class 'tweepy.models.Status'>>
# parse_list : <bound method type.parse_list of <class 'tweepy.models.Status'>>
# place : None
# possibly_sensitive : False
# retweet : <bound method Status.retweet of Status(contributors=None, truncated=False, text=u'RT @ProjectJupyter: Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. ht\u2026', is_quote_status=False, in_reply_to_status_id=None, id=727247974309339136, favorite_count=0, _api=<tweepy.api.API object at 0x103b91f10>, author=User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False), _json={u'contributors': None, u'truncated': False, u'text': u'RT @ProjectJupyter: F ...
# retweet_count : 12
# retweeted : False
# retweeted_status : Status(contributors=None, truncated=False, text=u'Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. https://t.co/VqlB9RyvpG', is_quote_status=False, in_reply_to_status_id=None, id=727166995024637952, favorite_count=7, _api=<tweepy.api.API object at 0x103b91f10>, author=User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=False, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': False, u'default_profile_image': False, u'id': 2460368252, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'profile_text_color': u'000000', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/510150524444749824/G9zPOizA_normal.png', u'profile_sidebar_fill_color': u'000000', u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/vc1eSiX5mA', u'indices': [0, 22], u'expanded_url': u'http://jupyter.org', u'display_url': u'jupyter.org'}]}, u'description': {u'urls': []}}, u'followers_count': 7414, u'profile_sidebar_border_color': u'000000', u'id_str': u'2460368252', u'profile_background_color': u'000000', u'listed_count': 263, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 569, u'description': u'Multi-language interactive computing environments. The future home of the IPython notebook and related projects (same folks, same code, new name, new repos).', u'friends_count': 32, u'location': u'The Future', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/510150524444749824/G9zPOizA_normal.png', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'ProjectJupyter', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 60, u'name': u'Project Jupyter', u'notifications': None, u'url': u'http://t.co/vc1eSiX5mA', u'created_at': u'Wed Apr 23 21:40:02 +0000 2014', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=None, id=2460368252, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'000000', profile_image_url_https=u'https://pbs.twimg.com/profile_images/510150524444749824/G9zPOizA_normal.png', profile_sidebar_fill_color=u'000000', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'http://t.co/vc1eSiX5mA', u'indices': [0, 22], u'expanded_url': u'http://jupyter.org', u'display_url': u'jupyter.org'}]}, u'description': {u'urls': []}}, followers_count=7414, protected=False, id_str=u'2460368252', default_profile_image=False, listed_count=263, lang=u'en', utc_offset=None, statuses_count=569, description=u'Multi-language interactive computing environments. The future home of the IPython notebook and related projects (same folks, same code, new name, new repos).', friends_count=32, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/510150524444749824/G9zPOizA_normal.png', notifications=None, profile_background_image_url_https=u'https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_color=u'000000', profile_background_image_url=u'http://abs.twimg.com/images/themes/theme1/bg.png', name=u'Project Jupyter', is_translation_enabled=False, profile_background_tile=False, favourites_count=60, screen_name=u'ProjectJupyter', url=u'http://t.co/vc1eSiX5mA', created_at=datetime.datetime(2014, 4, 23, 21, 40, 2), contributors_enabled=False, location=u'The Future', profile_sidebar_border_color=u'000000', default_profile=False, following=False), _json={u'contributors': None, u'truncated': False, u'text': u'Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. https://t.co/VqlB9RyvpG', u'is_quote_status': False, u' ...
# retweets : <bound method Status.retweets of Status(contributors=None, truncated=False, text=u'RT @ProjectJupyter: Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. ht\u2026', is_quote_status=False, in_reply_to_status_id=None, id=727247974309339136, favorite_count=0, _api=<tweepy.api.API object at 0x103b91f10>, author=User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False), _json={u'contributors': None, u'truncated': False, u'text': u'RT @ProjectJupyter: ...
# source : Twitter for Android
# source_url : http://twitter.com/download/android
# text : RT @ProjectJupyter: Final reminder to fill out the #Jupyter education survey if you teach with #Jupyter or #IPython! Closes this Friday. ht…
# truncated : False
# user : User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)

# %% [markdown]
# ### Inspecting a User Object

# %%
user=tweet.author

for param in dir(user):
    if not param.startswith("_"):
        print "%s : %s" % (param, eval("user." + param))
# Out:
# contributors_enabled : False
# created_at : 2007-06-21 22:11:56
# default_profile : False
# default_profile_image : False
# description : Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.
# entities : {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}
# favourites_count : 1313
# follow : <bound method User.follow of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# follow_request_sent : None
# followers : <bound method User.followers of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# followers_count : 223
# followers_ids : <bound method User.followers_ids of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# following : False
# friends : <bound method User.friends of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# friends_count : 96
# geo_enabled : False
# has_extended_profile : False
# id : 7005172
# id_str : 7005172
# is_translation_enabled : False
# is_translator : False
# lang : en
# listed_count : 270
# lists : <bound method User.lists of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# lists_memberships : <bound method User.lists_memberships of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# lists_subscriptions : <bound method User.lists_subscriptions of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# location : Brisbane Queensland
# name : Rowland Mosbergen
# notifications : None
# parse : <bound method type.parse of <class 'tweepy.models.User'>>
# parse_list : <bound method type.parse_list of <class 'tweepy.models.User'>>
# profile_background_color : 022330
# profile_background_image_url : http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg
# profile_background_image_url_https : https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg
# profile_background_tile : False
# profile_image_url : http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG
# profile_image_url_https : https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG
# profile_link_color : FA743E
# profile_sidebar_border_color : A8C7F7
# profile_sidebar_fill_color : C0DFEC
# profile_text_color : 333333
# profile_use_background_image : True
# protected : False
# screen_name : rowlandm
# statuses_count : 5329
# time_zone : Brisbane
# timeline : <bound method User.timeline of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# unfollow : <bound method User.unfollow of User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 7005172, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'profile_sidebar_fill_color': u'C0DFEC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, u'followers_count': 223, u'profile_sidebar_border_color': u'A8C7F7', u'id_str': u'7005172', u'profile_background_color': u'022330', u'listed_count': 270, u'is_translation_enabled': False, u'utc_offset': 36000, u'statuses_count': 5329, u'description': u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', u'friends_count': 96, u'location': u'Brisbane Queensland', u'profile_link_color': u'FA743E', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', u'following': None, u'geo_enabled': False, u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', u'screen_name': u'rowlandm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 1313, u'name': u'Rowland Mosbergen', u'notifications': None, u'url': u'https://t.co/JpLxpkTFaH', u'created_at': u'Thu Jun 21 22:11:56 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Brisbane', u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=u'Brisbane', id=7005172, _api=<tweepy.api.API object at 0x103b91f10>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', profile_sidebar_fill_color=u'C0DFEC', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/JpLxpkTFaH', u'indices': [0, 23], u'expanded_url': u'http://www.stemformatics.org', u'display_url': u'stemformatics.org'}]}, u'description': {u'urls': []}}, followers_count=223, protected=False, id_str=u'7005172', default_profile_image=False, listed_count=270, lang=u'en', utc_offset=36000, statuses_count=5329, description=u'Project Manager, Full Stack Developer, UX and BA. #bioinformatics, BioJS visualization and web frameworks for @Stemformatics. Loves #hackathons.', friends_count=96, profile_link_color=u'FA743E', profile_image_url=u'http://pbs.twimg.com/profile_images/1736419404/SAM_7610_normal.JPG', notifications=None, profile_background_image_url_https=u'https://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', profile_background_color=u'022330', profile_background_image_url=u'http://pbs.twimg.com/profile_background_images/396074674/2011-04-26_16.23.09.jpg', name=u'Rowland Mosbergen', is_translation_enabled=False, profile_background_tile=False, favourites_count=1313, screen_name=u'rowlandm', url=u'https://t.co/JpLxpkTFaH', created_at=datetime.datetime(2007, 6, 21, 22, 11, 56), contributors_enabled=False, location=u'Brisbane Queensland', profile_sidebar_border_color=u'A8C7F7', default_profile=False, following=False)>
# url : https://t.co/JpLxpkTFaH
# utc_offset : 36000
# verified : False

# %% [markdown]
# ### Using Cursor for Pagination

# %% [markdown]
# For data mining you will be dealing with a large amount of results. Cursor is a simple way to handle interation and results pages.

# %%
results = []
for tweet in tweepy.Cursor(api.search, q="IPython").items(100):
    results.append(tweet)

print len(results)
# Out:
# 100

# %% [markdown]
# ### Store Results in a Data Frame

# %%
def process_results(results):
    id_list = [tweet.id for tweet in results]
    data_set = pd.DataFrame(id_list, columns=["id"])

    # Processing Tweet Data

    data_set["text"] = [tweet.text for tweet in results]
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["favorite_count"] = [tweet.favorite_count for tweet in results]
    data_set["source"] = [tweet.source for tweet in results]

    # Processing User Data
    data_set["user_id"] = [tweet.author.id for tweet in results]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in results]
    data_set["user_name"] = [tweet.author.name for tweet in results]
    data_set["user_created_at"] = [tweet.author.created_at for tweet in results]
    data_set["user_description"] = [tweet.author.description for tweet in results]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_friends_count"] = [tweet.author.friends_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]

    return data_set
data_set = process_results(results)

# %% [markdown]
# ## Looking at the Data

# %%
data_set.head(5)
# Out:
#                    id                                               text          created_at  retweet_count  \
# 0  727247974309339136  RT @ProjectJupyter: Final reminder to fill out... 2016-05-02 21:26:43             12
# 1  727244304176021504  #Imbed matplotlib figure into iPython HTML\n#H... 2016-05-02 21:12:08              0
# 2  727232915306909697  #Automating ipython output to pdf\n#Tech #Ques... 2016-05-02 20:26:53              0
# 3  727232723430027264  #Automating ipython output to pdf\n#Tech #News... 2016-05-02 20:26:07              0
# 4  727226084257861636  RT @ProjectJupyter: Final reminder to fill out... 2016-05-02 19:59:44             12
#
#    favorite_count               source     user_id user_screen_name          user_name     user_created_at  \
# 0               0  Twitter for Android     7005172         rowlandm  Rowland Mosbergen 2007-06-21 22:11:56
# 1               0                IFTTT  4641990870   HartwigMicheal    Micheal Hartwig 2015-12-24 08:02:08
# 2               0                IFTTT  4635820598     startechwall     Star Tech Wall 2015-12-23 07:01:41
# 3               0                IFTTT  4387442232      AdamSmitht1  Daily Tech Issues 2015-11-28 11:03:01
# 4               0   Twitter for iPhone    37989702        kirstie_j   Kirstie Whitaker 2009-05-05 18:50:47
#
#                                     user_description  user_followers_count  user_friends_count        user_location
# 0  Project Manager, Full Stack Developer, UX and ...                   223                  96  Brisbane Queensland
# 1  Daily #Programming Issues: Stay connected & St...                   682                 825                   FR
# 2  Оставайтесь на связи с нами и следите за обнов...                   661                 848                   RU
# 3  Daily #Technology Issues & solutions: The heig...                  1027                 792                   CN
# 4  Postdoctoral fellow investigating brain develo...                   937                1317        Cambridge, UK

# %%
data_set.tail(5)
# Out:
#                     id                                               text          created_at  retweet_count  \
# 95  726864166582145024  Top 10 IPython Notebook #Tutorials for #DataSc... 2016-05-01 20:01:36             30
# 96  726848919620210688  How to calculate inner matrix product in Ipyth... 2016-05-01 19:01:01              0
# 97  726845654752854016  @clauersen Indeed... prob will for my current ... 2016-05-01 18:48:02              0
# 98  726820163035656193  RT @AnalyticsVidhya: How to transpose the high... 2016-05-01 17:06:45              1
# 99  726818666415853568  How to transpose the higher dimension matrix i... 2016-05-01 17:00:48              1
#
#     favorite_count     source     user_id user_screen_name          user_name     user_created_at  \
# 95              44  Hootsuite    20167623        kdnuggets  Gregory Piatetsky 2009-02-05 17:37:26
# 96               0     Buffer  2311645130  AnalyticsVidhya   Analytics Vidhya 2014-01-26 10:48:31
# 97               1  TweetDeck   845999910     zhao_shirley       Shirley Zhao 2012-09-25 18:26:20
# 98               0  Hootsuite    17982188    hendrosubagyo     hendro subagyo 2008-12-09 03:07:46
# 99               2     Buffer  2311645130  AnalyticsVidhya   Analytics Vidhya 2014-01-26 10:48:31
#
#                                      user_description  user_followers_count  user_friends_count       user_location
# 95  KDnuggets President, #Analytics, #BigData, #Da...                 55697                 407  Brookline, MA, USA
# 96  Join the largest analystics community https://...                  4779                 264
# 97  #medlibs #datalibs #scilibs #academic #librari...                   281                 394  Salt Lake City, UT
# 98                                  ora mandeg ngelmu                   282                 192             Jakarta
# 99  Join the largest analystics community https://...                  4779                 264

# %% [markdown]
# # Visualizing Results

# %%
sources = data_set["source"].value_counts()[:5][::-1]

plt.barh(xrange(len(sources)), sources.values)
plt.yticks(np.arange(len(sources)) + 0.4, sources.index)
plt.show()
